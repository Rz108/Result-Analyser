# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('subScore.csv')

#df = df.rename(columns={'Unnamed: 0': 'Name'})

display(df)
# Out:
#      Unnamed: 0  Numbers and their operations  Ratio and proportion  \
# 0             0                             2                     1
# 1             1                             2                     4
# 2             2                             2                     3
# 3             3                             4                     1
# 4             4                             2                     2
# ..          ...                           ...                   ...
# 995         995                             4                     3
# 996         996                             4                     1
# 997         997                             1                     2
# 998         998                             4                     2
# 999         999                             1                     3
#
#      Percentage  Rate and speed  Algebraic  expressions and formulae  \
# 0             1               1          1                         1
# ...

# %%
#function
def categorize_score(score):
    if score == 5:
        return "high"
    elif score == 4:
        return "middle"
    elif score == 3:
        return "middle"
    else:
        return "low"

# %%
math = df['Numbers and their operations'].tolist()
result_for_math = []
for i in math:
    grade = categorize_score(i)
    result_for_math.append(grade)
print(result_for_math)


math = df['Ratio and proportion'].tolist()
result_for_math2 = []
for i in math:
    grade = categorize_score(i)
    result_for_math2.append(grade)
print(result_for_math2)


math = df['Percentage'].tolist()
result_for_math3 = []
for i in math:
    grade = categorize_score(i)
    result_for_math3.append(grade)
print(result_for_math3)


math = df['Rate and speed'].tolist()
result_for_math2 = []
for i in math:
    grade = categorize_score(i)
    result_for_math2.append(grade)
print(result_for_math2)
# Out:
# ['middle', 'middle', 'middle', 'high', 'middle', 'low', 'low', 'low', 'low', 'middle', 'middle', 'low', 'middle', 'middle', 'middle', 'middle', 'middle', 'high', 'middle', 'low', 'middle', 'low', 'high', 'low', 'high', 'middle', 'middle', 'middle', 'middle', 'middle', 'middle', 'high', 'high', 'middle', 'middle', 'low', 'middle', 'low', 'middle', 'high', 'middle', 'middle', 'high', 'high', 'middle', 'low', 'high', 'high', 'middle', 'low', 'low', 'low', 'high', 'middle', 'middle', 'middle', 'middle', 'middle', 'high', 'high', 'middle', 'middle', 'low', 'high', 'middle', 'high', 'high', 'low', 'high', 'high', 'high', 'low', 'high', 'high', 'high', 'low', 'low', 'low', 'middle', 'low', 'middle', 'high', 'middle', 'high', 'high', 'high', 'low', 'middle', 'low', 'middle', 'high', 'middle', 'middle', 'low', 'low', 'low', 'middle', 'high', 'middle', 'high', 'middle', 'low', 'middle', 'low', 'low', 'middle', 'middle', 'low', 'middle', 'low', 'middle', 'low', 'high', 'high', 'middle', 'high',
# ...

# %%
for i in df.columns:
    math = df[i].tolist()
    result_for_math = []
    for j in math:
        grade = categorize_score(j)
        result_for_math.append(grade)
df[i] = result_for_math
# Out:
# ['low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
# ...
